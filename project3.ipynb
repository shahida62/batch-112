# %%
import pandas as pd

# %%
data = pd.read_csv("Customer_Order_data.csv")

# %%
data
# Out:
#    OrderID        Date    Product     Category  price  Quantity  Total  \
# 0   1001.0  2024-01-02      Mouse  Electronics    500         2    100
# 1   1002.0  2024-01-03        NaN  Electronics   1000         5     50
# 2   1003.0         NaN   Keyboard  Electronics  50000         3    600
# 3   1004.0  2024-01-05     Loptop  Electronics    700         1  55000
# 4   1005.0  2024-01-06  Headphone  Electronics  15000         6    400
# 5      NaN  2024-01-07    Printer  Electronics   3000         1    700
#
#    Customer_Age Payment_Method
# 0            23           Cash
# 1            31           Card
# 2            40         Online
# 3            50           Cash
# 4            55           Card
# 5            60         Online

# %%
data.isnull()
# Out:
#    OrderID   Date  Product  Category  price  Quantity  Total  Customer_Age  \
# 0    False  False    False     False  False     False  False         False
# 1    False  False     True     False  False     False  False         False
# 2    False   True    False     False  False     False  False         False
# 3    False  False    False     False  False     False  False         False
# 4    False  False    False     False  False     False  False         False
# 5     True  False    False     False  False     False  False         False
#
#    Payment_Method
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# 5           False

# %%
data.isnull().sum()
# Out:
# OrderID           1
# Date              1
# Product           1
# Category          0
# price             0
# Quantity          0
# Total             0
# Customer_Age      0
# Payment_Method    0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(3)
