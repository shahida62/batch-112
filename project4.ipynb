# %%
import pandas as pd

# %%
data = {
    "PassengerID": [1, 2, 3, 4, 5, 6, 7, 8, 9],
    "Survived": [0, 1, 2, 1, 3, 1, 4, 1, 5],  # fixed
    "Pclass": [3, 1, 3, 2, 1, 4, 2, 3, 4],     # fixed
    "Name": [
        "John Smith",
        "Anna Brown", 
        "Peter Wilson",
        "Mary Clark",
        "Edward Thomas",
        "Rebaka willam",
        "Josef Brown",
        "Merina Mask",
        "Bath Thomas"
    ],
    "Gender": ["Male", "Female", "Male", "Female", "Male", "Female", "Male", "Female", "Male"],
    "Age": [22, 38, 26, 35, 28, 40, 54, 33, 50],
    "SibSp": [1, 1, 1, 0, 1, 0, 1, 1, 0],
    "parch": [0, 0, 0, 0, 0, 0, 0, 0, 0],
    "Fare": [7.25, 71.28, 7.92, 53.10, 11.10, 51.23, 65.32, 45.21, 30.11],
    "Embarked": ["S", "C", "S", "S", "S", "C", "C", "S", "C"]
}

# %%
data = pd.DataFrame(data)

# %%
data.to_csv("Titanic_practice.csv", index=False)

# %%
data.head()
# Out:
#    PassengerID  Survived  Pclass           Name  Gender  Age  SibSp  parch  \
# 0            1         0       3     John Smith    Male   22      1      0
# 1            2         1       1     Anna Brown  Female   38      1      0
# 2            3         2       3   Peter Wilson    Male   26      1      0
# 3            4         1       2     Mary Clark  Female   35      0      0
# 4            5         3       1  Edward Thomas    Male   28      1      0
#
#     Fare Embarked
# 0   7.25        S
# 1  71.28        C
# 2   7.92        S
# 3  53.10        S
# 4  11.10        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerID  9 non-null      int64
#  1   Survived     9 non-null      int64
#  2   Pclass       9 non-null      int64
#  3   Name         9 non-null      object
#  4   Gender       9 non-null      object
#  5   Age          9 non-null      int64
#  6   SibSp        9 non-null      int64
#  7   parch        9 non-null      int64
#  8   Fare         9 non-null      float64
#  9   Embarked     9 non-null      object
# dtypes: float64(1), int64(6), object(3)
# memory usage: 852.0+ bytes

# %%
data.isnull().sum()
# Out:
# PassengerID    0
# Survived       0
# Pclass         0
# Name           0
# Gender         0
# Age            0
# SibSp          0
# parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
data.describe()
# Out:
#        PassengerID  Survived    Pclass        Age     SibSp  parch       Fare
# count     9.000000  9.000000  9.000000   9.000000  9.000000    9.0   9.000000
# mean      5.000000  2.000000  2.555556  36.222222  0.666667    0.0  38.057778
# std       2.738613  1.658312  1.130388  10.662760  0.500000    0.0  24.862544
# min       1.000000  0.000000  1.000000  22.000000  0.000000    0.0   7.250000
# 25%       3.000000  1.000000  2.000000  28.000000  0.000000    0.0  11.100000
# 50%       5.000000  1.000000  3.000000  35.000000  1.000000    0.0  45.210000
# 75%       7.000000  3.000000  3.000000  40.000000  1.000000    0.0  53.100000
# max       9.000000  5.000000  4.000000  54.000000  1.000000    0.0  71.280000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    PassengerID  Survived  Pclass           Name  Gender  Age  SibSp  parch  \
# 0            1         0       3     John Smith    Male   22      1      0
# 1            2         1       1     Anna Brown  Female   38      1      0
# 2            3         2       3   Peter Wilson    Male   26      1      0
# 3            4         1       2     Mary Clark  Female   35      0      0
# 4            5         3       1  Edward Thomas    Male   28      1      0
# 5            6         1       4  Rebaka willam  Female   40      0      0
# 6            7         4       2    Josef Brown    Male   54      1      0
# 7            8         1       3    Merina Mask  Female   33      1      0
# 8            9         5       4    Bath Thomas    Male   50      0      0
#
#     Fare Embarked
# 0   7.25        S
# 1  71.28        C
# 2   7.92        S
# 3  53.10        S
# 4  11.10        S
# 5  51.23        C
# 6  65.32        C
# 7  45.21        S
# 8  30.11        C

# %%
sns.countplot(x="Survived", data=df)
plt.title("Survival Count")
plt.show()

# %%
sns.countplot(x="Gender", hue="Survived", data=df)
plt.title("Gender vs Survival")
plt.show()

# %%
sns.countplot(x="Gender", hue="Age", data=df)
plt.title("Gender vs Age")
plt.show()

# %%
sns.histplot(df["Age"], kde=True)
plt.title("Age Distribution")
plt.show()
